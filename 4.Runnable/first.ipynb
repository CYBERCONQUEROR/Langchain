# %%
import random
class NakliLLM:
    def __init__(self):
        print("NakliLLM initialized")

    def predict(self,prompt):

        response_list=[
            'Delhi is the capital of India',
            'IPL is a cricket tournament',
            'Python is a programming language',
            'AI is the future',

        ]

        return {'response':random.choice(response_list)}

# %%
llm=NakliLLM()
# Out:
# NakliLLM initialized

# %%
llm.predict("What is the capital of India?")
# Out:
# {'response': 'AI is the future'}

# %%
class NakliPropmptTemplate:
    def __init__(self, template , input_variables):
        self.template=template
        self.input_variables=input_variables

    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPropmptTemplate(
    template = 'write a poem about {topic}',
    input_variables=['topic']
)

# %%
template.format({'topic' : 'india'})
# Out:
# 'write a poen about india'
